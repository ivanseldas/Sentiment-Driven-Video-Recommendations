# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_avg_emotions = pd.read_csv('../docker_app/df_avg_emotions.csv', index_col=0).set_index('video_id')
df_avg_emotions.head()
# Out:
#              final_emotion_score  admiration  amusement     anger  annoyance  \
# video_id
# 96-u9s6D16k             0.590317    0.348565   0.157720  0.031625   0.011238
# s1qZbsytk08             0.076762    0.208116   0.681874  0.087250   0.040555
# erFxR8DNu_Q             0.986885    0.013731   0.000000  0.000000   0.000000
# M9a0XrkdBf4             0.720563    0.906769   0.000000  0.000000   0.006454
# wQ8BIBpya2k             0.270706    0.411763   0.701196  0.142177   0.033375
#
#              approval    caring  confusion  curiosity    desire  ...  \
# video_id                                                         ...
# 96-u9s6D16k  0.044829  0.261016   0.009382   0.008693  0.109444  ...
# s1qZbsytk08  0.047845  0.267367   0.049068   0.053390  0.042061  ...
# erFxR8DNu_Q  0.014744  0.000000   0.000000   0.000000  0.000000  ...
# M9a0XrkdBf4  0.057067  0.000000   0.000000   0.000000  0.000000  ...
# wQ8BIBpya2k  0.053308  0.043760   0.224349   0.059109  0.135170  ...
#
# ...

# %%
video_id = np.random.choice(df_avg_emotions.index)
video_id
# Out:
# 'Fe04JM653fo'

# %% [markdown]
# * Average Emotion Score

# %%
plt.figure(figsize=(12,8))
df_avg_emotions.loc[video_id].sort_values(ascending=False).drop('final_emotion_score')[:10].sort_values(ascending=True).plot(kind='barh')
final_score = df_avg_emotions.loc[video_id]['final_emotion_score']
plt.title(f'[{video_id}] Final Score: {final_score}')
plt.show();
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
